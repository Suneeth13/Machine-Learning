# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
csv_path = "/content/drive/MyDrive/Colab Notebooks/annual-enterprise-survey-2021-financial-year-provisional-csv.csv"

# %%
df=pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
xlsx_path = '/content/drive/MyDrive/Colab Notebooks/tests-example.xls'

# %%
df=pd.read_excel(xlsx_path)

# %%
df.head()
# Out:
#     MC                                       What is 2+2?            4  \
# 0   MA         What C datatypes are 8 bits? (assume i386)          int
# 1   TF                              Bagpipes are awesome.         true
# 2  ESS  How have the original Henry Hornbostel buildin...          NaN
# 3  ORD    Rank the following in their order of operation.  Parentheses
# 4  FIB                      The student activities fee is           95
#
#                             correct         3       incorrect Unnamed: 6  \
# 0                               NaN     float             NaN     double
# 1                               NaN       NaN             NaN        NaN
# 2                               NaN       NaN             NaN        NaN
# 3                         Exponents  Division        Addition        NaN
# 4  dollars for students enrolled in        19  units or more,        NaN
#
#   Unnamed: 7 Unnamed: 8
# 0        NaN       char
# 1        NaN        NaN
# ...

# %%
Fruits={"apple":[3,2,1],"banana":[4,8,12],"Mango":[7,4,2],"Coconut":[6,2,3]}

# %%
Fruits_frame=pd.DataFrame(Fruits)

# %%
Fruits_frame.head()
# Out:
#    apple  banana  Mango  Coconut
# 0      3       4      7        6
# 1      2       8      4        2
# 2      1      12      2        3

# %%
x = Fruits_frame[["Mango"]]

# %%
x.head()
# Out:
#    Mango
# 0      7
# 1      4
# 2      2

# %%
Fruits_frame.iloc[0,0]
# Out:
# 3

# %%
df.iloc[3,4]
# Out:
# 'Division'

# %%
df.loc[3,"correct"]
# Out:
# 'Exponents'

# %%
z=df.loc[0:2,['correct','incorrect']]

# %%
z.head()
# Out:
#   correct incorrect
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN

# %%
new_index=['a', 'b', 'c', 'd', 'e', 'f']
df_new=df.copy()
df_new.index=new_index
df_new.loc['a', 'MC']
df_new.loc['a':'b', 'MC']
# Out:
# a    MA
# b    TF
# Name: MC, dtype: object

# %%
#1st problem
frame = {
    "Student": ["David", "Samuel", "Terry", "Evan"],
    "Country": ["UK", "Canada", "China", "USA"],
    "Course": ["python", "Data Structures", "Machine learning", "Web Development"],
    "Marks": [85, 72, 89, 76]
}
x = pd.DataFrame(frame)

# %%
x.head()
# Out:
#   Student Country            Course  Marks
# 0   David      UK            python     85
# 1  Samuel  Canada   Data Structures     72
# 2   Terry   China  Machine learning     89
# 3    Evan     USA   Web Development     76

# %%
b = x[["Marks"]]
b
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %%
c = x[["Country", "Course"]]
c
# Out:
#   Country            Course
# 0      UK            python
# 1  Canada   Data Structures
# 2   China  Machine learning
# 3     USA   Web Development

# %%
x["Student"]
# Out:
# 0     David
# 1    Samuel
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %%
a1 = x.iloc[0,0]
a1
# Out:
# 'David'

# %%
a2 = x.iloc[0,3]
a2
# Out:
# 85

# %%
a3 = x.loc[0, ["Student"]]
a3
# Out:
# Student    David
# Name: 0, dtype: object

# %%
df1=x.copy()
df1=df1.set_index("Student")
df1.head()
# Out:
#         Country            Course  Marks
# Student
# David        UK            python     85
# Samuel   Canada   Data Structures     72
# Terry     China  Machine learning     89
# Evan        USA   Web Development     76

# %%
df1.loc['Terry', 'Marks']
# Out:
# 89

# %%
data = {
    "Artist": ["Michael Jackson", "AC/DC", "Pink Floyd", "Whitney Houston", "Meat Loaf", "Eagles", "Bee Gees", "Fleetwood Mac"],
    "Album": ["Thriller", "Back in Black", "The Dark Side of the Moon", "The Bodyguard", "Bat Out of Hell", "Their Greatest Hits", "Saturday Night Fever", "Rumours"],
    "Released": [1982, 1980, 1973, 1992, 1977, 1976, 1977, 1977],
    "Length": ["0:42:19", "0:42:11", "0:42:49", "0:57:44", "0:46:33", "0:43:08", "1:15:54", "0:40:01"],
    "Genre": ["pop, rock, R&B", "hard rock", "progressive rock", "R&B, soul, pop", "hard rock, progressive rock", "rock, soft rock, folk rock", "disco", "soft rock"],
    "Music Recording Sales": [46.0, 26.1, 24.2, 27.4, 20.6, 32.2, 20.6, 27.9],
    "Claimed Sales": [65, 500, 45, 44, 43, 42, 40, 40],
    "Released.1": ["30-Nov-82", "25-Jul-80", "01-Mar-73", "17-Nov-92", "21-Oct-77", "17-Feb-76", "15-Nov-77", "04-Feb-77"],
    "Soundtrack": [np.nan, np.nan, np.nan, 'Y', np.nan, np.nan, 'Y', np.nan],
    "Rating": [10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 7.0, 6.5]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
# 5           Eagles        Their Greatest Hits      1976  0:43:08
# 6         Bee Gees       Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                    Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales  Claimed Sales  \
# 0               pop, rock, R&B                   46.0             65
# 1                    hard rock                   26.1            500
# 2             progressive rock                   24.2             45
# 3               R&B, soul, pop                   27.4             44
# ...

# %%
df['Released']>=1980
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# Name: Released, dtype: bool

# %%
df1 = df[df['Released'] >= 1980]

# %%
df1
# Out:
#             Artist          Album  Released   Length           Genre  \
# 0  Michael Jackson       Thriller      1982  0:42:19  pop, rock, R&B
# 1            AC/DC  Back in Black      1980  0:42:11       hard rock
# 3  Whitney Houston  The Bodyguard      1992  0:57:44  R&B, soul, pop
#
#    Music Recording Sales  Claimed Sales Released.1 Soundtrack  Rating
# 0                   46.0             65  30-Nov-82        NaN    10.0
# 1                   26.1            500  25-Jul-80        NaN     9.5
# 3                   27.4             44  17-Nov-92          Y     8.5

# %%
df1.to_csv("filtered data.csv")

# %%
df = pd.DataFrame({"a": [1,2,1], "b": [1,1,1]})
df
# Out:
#    a  b
# 0  1  1
# 1  2  1
# 2  1  1

# %%
unique_values_a = df['a'].unique()

# %%
print(unique_values_a)
# Out:
# [1 2]

# %%
filtered_df = df[df['a'] < 2]
print(filtered_df)
# Out:
#    a  b
# 0  1  1
# 2  1  1

# %%
a = [
    [11,12,13],
    [21,22,23],
    [31,32,33]
]
A = np.array(a)
A
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %%
A.ndim
# Out:
# 2

# %%
A.shape
# Out:
# (3, 3)

# %%
A[0][2]
# Out:
# 13

# %%
A[0,0:2]
# Out:
# array([11, 12])

# %%
A[0:2,2]
# Out:
# array([13, 23])

# %%
X = np.array([[1,0],[0,1]])
Y = np.array([[2,1],[1,2]])
Z = X + Y
Z
# Out:
# array([[3, 1],
#        [1, 3]])

# %%
Z = 2 * Y
Z
# Out:
# array([[4, 2],
#        [2, 4]])

# %%
Z = X * Y
Z
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
A = np.array([[0,1,1],[1,0,1]])
B = np.array([[1,1],[1,1],[-1,1]])
C = np.dot(A,B)
C
# Out:
# array([[0, 2],
#        [0, 2]])

# %%
dict = {
    "highway-mpg": ["...", 20,22,29,"..."],
    "price": ["...", 23875,np.nan,16430,"..."]
}

# %%
df = pd.DataFrame(dict)
df
# Out:
#   highway-mpg  price
# 0         ...    ...
# 1          20  23875
# 2          22    NaN
# 3          29  16430
# 4         ...    ...

# %%
df.dropna(subset = ["price"], axis = 0, inplace = True)

# %%
df
# Out:
#   highway-mpg  price
# 0         ...    ...
# 1          20  23875
# 3          29  16430
# 4         ...    ...

# %%
dict = {
    "normalized-losses" : [150, 164, 164, np.nan, 158, 165],
    "make": ["...", "audi", "audi", "audi", "audi","..."]
}
df = pd.DataFrame(dict)
df
# Out:
#    normalized-losses  make
# 0              150.0   ...
# 1              164.0  audi
# 2              164.0  audi
# 3                NaN  audi
# 4              158.0  audi
# 5              165.0   ...

# %%
mean = df["normalized-losses"].mean()
df["normalized-losses"] = df["normalized-losses"].replace(np.nan,mean)
df
# Out:
#    normalized-losses  make
# 0              150.0   ...
# 1              164.0  audi
# 2              164.0  audi
# 3              160.2  audi
# 4              158.0  audi
# 5              165.0   ...

# %%
dict = {
    "city-mpg": [21,21,19,20]
}
df = pd.DataFrame(dict)
df
# Out:
#    city-mpg
# 0        21
# 1        21
# 2        19
# 3        20

# %%
df["city-L/100km"] = 235/df["city-mpg"]

# %%
df
# Out:
#     city-mpg  city-L/100km
# 0  11.190476          21.0
# 1  11.190476          21.0
# 2  12.368421          19.0
# 3  11.750000          20.0

# %%
df.dtypes
# Out:
# city-mpg        float64
# city-L/100km    float64
# dtype: object

# %%
df["city-L/100km"] = df["city-L/100km"].astype("int")
df.dtypes
# Out:
# city-mpg        float64
# city-L/100km      int64
# dtype: object

# %%
df
# Out:
#     city-mpg  city-L/100km
# 0  11.190476            21
# 1  11.190476            21
# 2  12.368421            19
# 3  11.750000            20

# %%
#Normalization
dict = {
    "length": [168.8,168.8,180.0],
    "width": [64.1, 64.1,65.5],
    "height": [48.8,48.8,52.4]
}
df = pd.DataFrame(dict)
df
# Out:
#    length  width  height
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   180.0   65.5    52.4

# %%
#Simple feature Scaling
df['length'] = df['length']/df['length'].max()

# %%
df
# Out:
#      length  width  height
# 0  0.937778   64.1    48.8
# 1  0.937778   64.1    48.8
# 2  1.000000   65.5    52.4

# %%
#Min-Max method
dict = {
    "length": [168.8,168.8,180.0],
    "width": [64.1, 64.1,65.5],
    "height": [48.8,48.8,52.4]
}
df = pd.DataFrame(dict)
df['length'] = (df['length'] - df['length'].min()) / (df['length'].max() - df['length'].min())
df
# Out:
#    length  width  height
# 0     0.0   64.1    48.8
# 1     0.0   64.1    48.8
# 2     1.0   65.5    52.4

# %%
#Z-Score
dict = {
    "length": [168.8,168.8,180.0],
    "width": [64.1, 64.1,65.5],
    "height": [48.8,48.8,52.4]
}
df = pd.DataFrame(dict)
df['length'] = (df['length'] - df['length'].mean()) / (df['length'].std())
df
# Out:
#      length  width  height
# 0 -0.577350   64.1    48.8
# 1 -0.577350   64.1    48.8
# 2  1.154701   65.5    52.4

# %%
#Binning
dict = {
    "price": [13495,16500,18920,41315,5151,6295]
}
df = pd.DataFrame(dict)
df
# Out:
#    price
# 0  13495
# 1  16500
# 2  18920
# 3  41315
# 4   5151
# 5   6295

# %%
bins = np.linspace(min(df['price']), max(df['price']), 4)
group_names = ['low','medium','high']
df['price-binned'] = pd.cut(df['price'],bins,labels = group_names,include_lowest = True)
df
# Out:
#    price price-binned
# 0  13495          low
# 1  16500          low
# 2  18920       medium
# 3  41315         high
# 4   5151          low
# 5   6295          low

# %%
dict = {
    "Car": ["A","B","C","D"],
    "Fuel": ["gas", "diesel", "gas","gas"]
}
df = pd.DataFrame(dict)
df
# Out:
#   Car    Fuel
# 0   A     gas
# 1   B  diesel
# 2   C     gas
# 3   D     gas

# %%
pd.get_dummies(df['Fuel'])
# Out:
#    diesel  gas
# 0       0    1
# 1       1    0
# 2       0    1
# 3       0    1

# %%
data = {
    "Artist": ["Michael Jackson", "AC/DC", "Pink Floyd", "Whitney Houston", "Meat Loaf", "Eagles", "Bee Gees", "Fleetwood Mac"],
    "Album": ["Thriller", "Back in Black", "The Dark Side of the Moon", "The Bodyguard", "Bat Out of Hell", "Their Greatest Hits", "Saturday Night Fever", "Rumours"],
    "Released": [1982, 1980, 1973, 1992, 1977, 1976, 1977, 1977],
    "Length": ["0:42:19", "0:42:11", "0:42:49", "0:57:44", "0:46:33", "0:43:08", "1:15:54", "0:40:01"],
    "Genre": ["pop, rock, R&B", "hard rock", "progressive rock", "R&B, soul, pop", "hard rock, progressive rock", "rock, soft rock, folk rock", "disco", "soft rock"],
    "Music Recording Sales": [46.0, 26.1, 24.2, 27.4, 20.6, 32.2, 20.6, 27.9],
    "Claimed Sales": [65, 500, 45, 44, 43, 42, 40, 40],
    "Released.1": ["30-Nov-82", "25-Jul-80", "01-Mar-73", "17-Nov-92", "21-Oct-77", "17-Feb-76", "15-Nov-77", "04-Feb-77"],
    "Soundtrack": [np.nan, np.nan, np.nan, 'Y', np.nan, np.nan, 'Y', np.nan],
    "Rating": [10.0, 9.5, 9.0, 8.5, 8.0, 7.5, 7.0, 6.5]
}
df = pd.DataFrame(data)
df
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
# 5           Eagles        Their Greatest Hits      1976  0:43:08
# 6         Bee Gees       Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                    Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales  Claimed Sales  \
# 0               pop, rock, R&B                   46.0             65
# 1                    hard rock                   26.1            500
# 2             progressive rock                   24.2             45
# 3               R&B, soul, pop                   27.4             44
# ...

# %%
df.describe()
# Out:
#           Released  Music Recording Sales  Claimed Sales     Rating
# count     8.000000               8.000000       8.000000   8.000000
# mean   1979.250000              28.125000     102.375000   8.250000
# std       5.800246               8.189322     160.869901   1.224745
# min    1973.000000              20.600000      40.000000   6.500000
# 25%    1976.750000              23.300000      41.500000   7.375000
# 50%    1977.000000              26.750000      43.500000   8.250000
# 75%    1980.500000              28.975000      50.000000   9.125000
# max    1992.000000              46.000000     500.000000  10.000000

# %%
x = df["Released"].value_counts()
x
# Out:
# 1977    3
# 1982    1
# 1980    1
# 1973    1
# 1992    1
# 1976    1
# Name: Released, dtype: int64

# %%
dict = {
    "drive-wheels":[2,2,2,4,4,4],
    "price": [20000,40000,60000,801110,470000,560000]
}
df = pd.DataFrame(dict)
df
# Out:
#    drive-wheels   price
# 0             2   20000
# 1             2   40000
# 2             2   60000
# 3             4  801110
# 4             4  470000
# 5             4  560000

# %%
import matplotlib.pyplot as plt
df.boxplot(column='price', by='drive-wheels')
plt.title('Boxplot of Price by Drive Wheels')
plt.xlabel('Drive Wheels')
plt.ylabel('Price')
plt.show()

# %%
y = df['drive-wheels']
x = df['price']
plt.scatter(x,y)
plt.title("Scatterplot of drive-wheels vs price")
plt.xlabel('drive-wheels')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')
