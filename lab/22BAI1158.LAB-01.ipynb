# %%
import pandas as pd
import numpy as np

# %%
print(type(21))
# Out:
# <class 'int'>

# %%
#TYPECASTING
print(float(2))
# Out:
# 2.0

# %%
print(int(2.6))
# Out:
# 2

# %%
print(int("a"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12330/3352567014.py in <module>
# ----> 1 print(int("a"))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
print(str(2))
# Out:
# 2

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(int(False))
# Out:
# 0

# %%
print(int(True))
# Out:
# 1

# %%
print(bool(1))
print(bool(0))
# Out:
# True
# False

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5//2)
# Out:
# 2

# %%
Name="Michael Jackson"
print(Name[0])
print(Name[::2])
print(Name[0:5:2])
# Out:
# M
# McalJcsn
# Mca

# %%
print(len(Name))
# Out:
# 15

# %%
Statement=Name+" is the best"
print(Statement)
# Out:
# Michael Jackson is the best

# %%
print(3*Name)
# Out:
# Michael JacksonMichael JacksonMichael Jackson

# %%
Name="MJ"
Name[0]="k"
Name="jj"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12330/3003059663.py in <module>
#       1 Name="MJ"
# ----> 2 Name[0]="k"
#       3 Name="jj"
#
# TypeError: 'str' object does not support item assignment

# %%
Name="Michael Jackson"
Newname=Name.replace("Michael","Jannet")
print(Newname)
# Out:
# Jannet Jackson

# %%
print("Michael Jackson \\ is the best")
print("Michael Jackson \+ is the best")
# Out:
# Michael Jackson \ is the best
# Michael Jackson \+ is the best

# %%
print(r"MJ \ is the best")
# Out:
# MJ \ is the best

# %%
A="Thriller is the sixth studio album"
B=A.upper()
print(B)
# Out:
# THRILLER IS THE SIXTH STUDIO ALBUM

# %%
#Find the length of substr
Name="My name is Suneeth"
print(Name.find('is'))
# Out:
# 8

# %%
#Assignment-01
#1.Print "Hello" and "World" on separate lines using print
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
#2.Find type "Hello world" and 1.1
print(type("Hello World"))
print(type(1.1))
# Out:
# <class 'str'>
# <class 'float'>

# %%
#3.Cast into bool "1"
print(bool("1"))
# Out:
# True

# %%
#4.find first 4 elements "ABCDEFGHIJK"
a="ABCDEFGHIJK"
print(a[:4])
# Out:
# ABCD

# %%
#Use a stride value of 2 on "GsoAo+d"
result = "GsoAo+d"[::2]
print(result)
# Out:
# Good

# %%
#convert string into upper "uppercase"
a="uppercase"
print(a.upper())
# Out:
# UPPERCASE

# %%
#Version of python used
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
#Wrting comments in python
#Single line comments #
'''
Multiline comments
'''
# Out:
# '\nMultiline comments\n'

# %%
#System settings about float type
print(sys.float_info)
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
#convert numbers 1 and 1.2 into str
print(str(1))
print(str(1.2))
# Out:
# 1
# 1.2

# %%
#data type of result 6/2 and 6//2
print(type(6/2))
print(type(6//2))
# Out:
# <class 'float'>
# <class 'int'>

# %%
#Let a="1" and b="2" execute c=a+b print c
a="1"
b="2"
c=a+b
print(c)
# Out:
# 12

# %%
#from d=ABCDEFGH print substr DEF
d="ABCDEFGH"
print(d[3:6])
# Out:
# DEF

# %%
print("\\")
print("\\\")
# Out:
#   File "<ipython-input-17-38fc16d7a869>", line 2
#     print("\\\")
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#find first index of var g="snow"
g="Mary had a little lamb Little lamb,little lamb Mary had a little lamb Its fleece was white as snow And everywhere that Mary went Mary went,Mary went Everywhere that Mary went The lamb was sure to go"
print(g.find("snow"))
# Out:
# 94

# %%
#In g,replace mary by bob
b=g.replace("Mary","Bob")
print(b)
# Out:
# Bob had a little lamb Little lamb,little lamb Bob had a little lamb Its fleece was white as snow And everywhere that Bob went Bob went,Bob went Everywhere that Bob went The lamb was sure to go

# %%
a=[23,45,34,56,67,78,78,89,56,45,12]
print(a[4:])
# Out:
# [67, 78, 78, 89, 56, 45, 12]
